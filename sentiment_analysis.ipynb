# %%
import pandas as pd
import requests
from datetime import datetime
import pytz
from datasets import load_dataset
import os
import time
import re
from transformers import AutoTokenizer, pipeline
from tqdm import tqdm

# %%
stocks = ['GME', 'AMC', 'TLRY', 'SNDL', 'NAKD', 'ZOM', 'AAPL', 'TSLA', 'GOEV', 'PLUG']

data1 = pd.read_csv("twitter_data/stock_social_data.csv")
data2 = pd.read_csv("twitter_data/stock_tweets.csv")
data2.rename(columns={'Date': 'created_at', 'Tweet': 'text', 'Stock Name': 'stock'}, inplace=True)
data2 = data2[data2['stock'].isin(stocks)]

# %%
# start_date = '2020-01-01'
# end_date = '2023-12-31'

# for stock in stocks:
#     query = f"${stock} since:{start_date} until:{end_date}"
#     output_file = f"{stock.lower()}_tweets.json"
#     command = f"snscrape --jsonl --max-results 100000 --progress twitter-search \"{query}\" > twitter_data/{output_file}"
#     os.system(command)

# %%
# import pandas as pd
# import json

# def load_tweets(json_file):
#     tweets = []
#     with open(json_file, 'r') as f:
#         for line in f:
#             tweet = json.loads(line)
#             tweets.append({
#                 'id': tweet['id'],
#                 'date': tweet['date'],
#                 'content': tweet['content'],
#                 'username': tweet['user']['username'],
#                 'likeCount': tweet['likeCount'],
#                 'retweetCount': tweet['retweetCount']
#             })
#     return pd.DataFrame(tweets)

# df_tsla = load_tweets('twitter_data/tsla_tweets.json')
# print(df_tsla.head())

# %%
def clean_text(text):
    """
    Clean tweet text by removing URLs, mentions, hashtags, excessive whitespace, and keeps tickers like $TSLA intact for sentiment context.
    
    Args:
        text (str): Input text.
    Returns:
        str: Cleaned text.
    """
    if pd.isna(text):
        return ""

    text = re.sub(r'http\S+|www\S+', '', text)       # Remove URLs
    text = re.sub(r'@\w+', '', text)                 # Remove mentions
    text = re.sub(r'#\w+', '', text)                 # Remove hashtags
    text = re.sub(r'\s+', ' ', text)                 # Normalize whitespace
    text = re.sub(r'[^\w\s\$]', '', text)            # Remove punctuations (except $)
    text = text.lower().strip()                      # Lowercase and strip

    return text

def extract_stock(text, stocks):
    """
    Extract all matching stock tickers from text, return as semicolon-separated string.
    
    Args:
        text (str): Cleaned tweet text.
        stocks (list): List of stock tickers to match.
    Returns:
        str or None: Semicolon-separated tickers (e.g., 'GME;AMC') or None if no match.
    """
    if not text:
        return None
    # Match tickers with or without $, case-insensitive
    stock_pattern = r'\$?(?:' + '|'.join([re.escape(s) for s in stocks]) + r')\b'
    matches = re.findall(stock_pattern, text, re.IGNORECASE)
    # Collect unique valid tickers
    tickers = list(dict.fromkeys([m.replace('$', '').upper() for m in matches if m.replace('$', '').upper() in stocks]))
    return ';'.join(tickers) if tickers else None


data1['clean_text'] = data1['text'].apply(clean_text)
data2['clean_text'] = data2['text'].apply(clean_text)

# Convert to datetime
data1['created_at'] = pd.to_datetime(data1['created_at'], errors='coerce', utc=True)
data1['date'] = data1['created_at'].dt.date
data2['created_at'] = pd.to_datetime(data2['created_at'], errors='coerce', utc=True)
data2['date'] = data2['created_at'].dt.date

# Extracting stock names
data1['stock'] = data1['clean_text'].apply(lambda x: extract_stock(x, stocks))

# Combine both datasets
data = pd.concat([data1[['created_at', 'date', 'text', 'clean_text', 'stock']], data2[['created_at', 'date', 'text', 'clean_text', 'stock']]], ignore_index=True)
data
# Out:
#                       created_at        date  \
# 0      2020-04-09 23:56:58+00:00  2020-04-09
# 1      2020-04-09 23:56:51+00:00  2020-04-09
# 2      2020-04-09 23:55:05+00:00  2020-04-09
# 3      2020-04-09 23:54:47+00:00  2020-04-09
# 4      2020-04-09 23:54:28+00:00  2020-04-09
# ...                          ...         ...
# 193809 2021-09-30 15:37:52+00:00  2021-09-30
# 193810 2021-09-30 15:30:03+00:00  2021-09-30
# 193811 2021-09-30 13:36:10+00:00  2021-09-30
# 193812 2021-09-30 10:22:53+00:00  2021-09-30
# 193813 2021-09-30 10:19:31+00:00  2021-09-30
#
#                                                      text  \
# 0       RT @TDANetwork: 📽️ #TheWatchList panel assesse...
# 1       $UMRX bouncing. EXTREMELY OVERSOLD #Coronaviru...
# 2       $AAPL 4h/1h\n\nSometimes these wedges break hi...
# 3       This week's Expired Signals are now published ...
# 4       $SPY $QQQ $VXX $AAPL $BA $MSFT\n\nGuys, I figu...
# ...                                                   ...
# ...

# %%
model_name = "yiyanghkust/finbert-tone"
tokenizer = AutoTokenizer.from_pretrained(model_name)

finbert = pipeline("sentiment-analysis", model=model_name, tokenizer=tokenizer)
def analyze_sentiment_finbert(text):
    """
    Perform sentiment analysis using FinBERT.
    
    Args:
        text (str): Input text.
    Returns:
        dict: Sentiment label (positive, negative, neutral) and score.
    """
    if not text:
        return {'label': 'neutral', 'score': 0.0}
    try:
        # Tokenize and truncate safely
        result = finbert(text, truncation=True, max_length=512)[0]
        return {'label': result['label'].lower(), 'score': result['score']}
    
    except:
        return {'label': 'neutral', 'score': 0.0}
    
def batch_sentiment_analysis(texts, batch_size=32):
    """
    Apply FinBERT sentiment analysis in batches.
    
    Args:
        texts (list): List of cleaned texts.
        batch_size (int): Number of texts per batch.
    
    Returns:
        list of dicts: Each dict has 'label' and 'score'
    """
    results = []
    for i in tqdm(range(0, len(texts), batch_size), desc="FinBERT Sentiment"):
        batch = texts[i:i+batch_size]
        try:
            preds = finbert(batch, truncation=True, max_length=512)
            results.extend([
                {'label': pred['label'].lower(), 'score': pred['score']}
                for pred in preds
            ])
        except Exception as e:
            print(f"Error in batch {i}: {e}")
            results.extend([{'label': 'neutral', 'score': 0.0}] * len(batch))
    return results
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
# Clean text and apply FinBERT sentiment analysis
# print("Applying FinBERT sentiment analysis...")
# sentiment_results = data['clean_text'].apply(analyze_sentiment_finbert)
# data['sentiment_label'] = sentiment_results.apply(lambda x: x['label'])
# data['sentiment_score'] = sentiment_results.apply(lambda x: x['score'])
# data

print("Applying FinBERT sentiment analysis (batch mode)...")
texts = data['clean_text'].tolist()
sentiment_results = batch_sentiment_analysis(texts, batch_size=32)

# Convert list of dicts into DataFrame
sentiment_df = pd.DataFrame(sentiment_results)
data['sentiment_label'] = sentiment_df['label']
data['sentiment_score'] = sentiment_df['score']
data
# Out:
# Applying FinBERT sentiment analysis (batch mode)...
# FinBERT Sentiment:  87%|████████▋ | 5292/6057 [4:54:08<29:07:50, 137.09s/it]

# %%
final = data.loc[:, ['date', 'created_at', 'stock', 'clean_text', 'sentiment_label', 'sentiment_score']]
final.to_csv("twitter_data/final_stock_social_sentiment_data.csv", index=False)
final
# Out:
#               date                created_at               stock  \
# 0       2020-04-09 2020-04-09 23:56:58+00:00                AAPL
# 1       2020-04-09 2020-04-09 23:56:51+00:00  AAPL;TSLA;TLRY;GME
# 2       2020-04-09 2020-04-09 23:55:05+00:00                AAPL
# 3       2020-04-09 2020-04-09 23:54:47+00:00                AAPL
# 4       2020-04-09 2020-04-09 23:54:28+00:00                AAPL
# ...            ...                       ...                 ...
# 193809  2021-09-30 2021-09-30 15:37:52+00:00                AAPL
# 193810  2021-09-30 2021-09-30 15:30:03+00:00                AAPL
# 193811  2021-09-30 2021-09-30 13:36:10+00:00                AAPL
# 193812  2021-09-30 2021-09-30 10:22:53+00:00                AAPL
# 193813  2021-09-30 2021-09-30 10:19:31+00:00                AAPL
#
#                                                clean_text sentiment_label  \
# 0       RT : 📽️ panel assesses the big questions $AAPL...         neutral
# ...

# %%
final['sentiment_label'].value_counts()
# Out:
# sentiment_label
# neutral     148184
# positive     34841
# negative     10789
# Name: count, dtype: int64
